# %%
#import the library
import pandas as pd 
import matplotlib.pyplot as plt
#read the data 
x=int(input('enter\n 1-if format is .csv\n 2-if format is .excel\n 3-if format is .sql \n '))
if x==1:
    df=pd.read_csv(input('enter the data address: '))
elif x==2:
    df=pd.read_excel(input('enter the data address: '))
elif x==2:
    df=pd.read_sql(input('enter the data address: '))
#test if their is nulls 
if df.isna().sum() is True:
    df=df.dropna()
#plot every column in Histogram fig
lst=list(df.columns)
print('\t\t Describtion for the data\n',df.describe())
for i in lst:
    try:
             x,y,z=plt.hist(df[i],bins=5,linewidth=5,edgecolor='w')
    except  TypeError:
             plt.title(str(df[i].name))
             print('thier column have a problem that i can''t know it  ')
    plt.title(str(df[i].name))
    for i in range(0,len(z)//3):
        z[i].set_facecolor('b')
    for i in range(len(z)//3,2*len(z)//3):
        z[i].set_facecolor('r')
    for i in range(2*len(z)//3,len(z)):
        z[i].set_facecolor('green')
    plt.xlabel('in')
    plt.ylabel('the amount')
    plt.show()
# if the user want to compare between the effect of two columns in another columns in (scatter fig)
x=input('if  you want to compare between two columns in scatter plot \nenter: y , if No enter :n  ')
while x=='y':
    if  x=='y':
        c=input('enter column name that is common betwee as it written: ')
        j=input('y_label of the graph: ')
        e=input('the title of the graph: ')
        print('----------------------------------------------------------------')
        v=input('enter the first column in compression:  ' )
        g=input('enter the label of the first scatter: ')
        #k=input('enter the color of the first scatter: ')
        #p=input('choose a mareker from this list[d,1] ')
        print('----------------------------------------------------------------')
        n=input('enter the second column in compression:  ' )
        f=input('enter the label of the second scatter: ')
        #w=input('enter the color of the first scatter: ')
        #l=input('choose a mareker from this list[d,1] ')
        plt.scatter(df[c],df[v],label=g)
        plt.scatter(df[c],df[n],label=f)
        plt.xlabel(df[c].name)
        plt.ylabel(j)
        plt.title(e)
        plt.legend()
        plt.show()
    else:
        break
    x=input('if  you want to compare between two columns in scatter plot \nenter: y , if No enter :n  ')
# Out:
# enter
#  1-if format is .csv
#  2-if format is .excel
#  3-if format is .sql
#  1
# enter the data address: International_Report_Departures.csv
# 		 Describtion for the data
#                  Year          Month     usg_apt_id        usg_wac  \
# count  930808.000000  930808.000000  930808.000000  930808.000000
# mean     2006.021361       6.414783   12809.473781      42.511740
# std         8.558831       3.471070    2716.223845      27.571338
# min      1990.000000       1.000000   10010.000000       1.000000
# 25%      1999.000000       3.000000   11618.000000      22.000000
# 50%      2007.000000       6.000000   12892.000000      33.000000
# 75%      2014.000000       9.000000   13487.000000      72.000000
# max      2020.000000      12.000000   99999.000000      93.000000
#
#            fg_apt_id         fg_wac      airlineid   carriergroup  \
# count  930808.000000  930808.000000  930808.000000  930808.000000
# ...

# %%
df.convert_dtypes().dtypes
# Out:
# data_dte        string
# Year            string
# Month           string
# usg_apt_id      string
# usg_apt         string
# usg_wac         string
# fg_apt_id       string
# fg_apt          string
# fg_wac          string
# airlineid       string
# carrier         string
# carriergroup    string
# type            string
# Scheduled       string
# Charter         string
# Total           string
# dtype: object

# %%
f=pd.read_csv('International_Report_Departures.csv')
f
International_Report_Departures.csv
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 0       05/01/2006  2006      5       12016     GUM        5      13162
# 1       05/01/2003  2003      5       10299     ANC        1      13856
# 2       03/01/2007  2007      3       10721     BOS       13      12651
# 3       12/01/2004  2004     12       11259     DAL       74      16271
# 4       05/01/2009  2009      5       13303     MIA       33      11075
# ...            ...   ...    ...         ...     ...      ...        ...
# 930803  07/01/2000  2000      7       13303     MIA       33      13605
# 930804  04/01/2019  2019      4       13303     MIA       33      14286
# 930805  08/01/2000  2000      8       13303     MIA       33      13605
# 930806  09/01/2004  2004      9       12266     IAH       74      15632
# 930807  05/01/1996  1996      5       12478     JFK       22      14210
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# ...

# %%
from sklearn.preprossing import LabelEncoder
data_dte=LabelEncoder()
df[0,:]=
